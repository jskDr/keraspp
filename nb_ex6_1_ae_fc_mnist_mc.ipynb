# %% [markdown]
# # 예제 6-1 완전 연결 계층을 이용한 AE

# %%
# %load /home/sjkim/.jupyter/head.py
# %%writefile /home/sjkim/.jupyter/head.py
# %load /home/sjkim/.jupyter/head.py
# %matplotlib inline
# %load_ext autoreload 
# %autoreload 2
from importlib import reload

import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# seaborn
import seaborn as sns
sns.set( style = 'white', font_scale = 1.7)
sns.set_style('ticks')
plt.rcParams['savefig.dpi'] = 200

# font for matplotlib
import matplotlib
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)

# %%
import ex6_1_ae_fc_mnist_mc as example
# Out:
# Using TensorFlow backend.
# (60000, 784)
# (10000, 784)

# %%
example.main()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 2s - loss: 0.3695 - acc: 0.7493 - val_loss: 0.2735 - val_acc: 0.7953
# Epoch 2/10
# 60000/60000 [==============================] - 1s - loss: 0.2672 - acc: 0.7966 - val_loss: 0.2578 - val_acc: 0.7967
# Epoch 3/10
# 60000/60000 [==============================] - 1s - loss: 0.2471 - acc: 0.7978 - val_loss: 0.2336 - val_acc: 0.7963
# Epoch 4/10
# 60000/60000 [==============================] - 1s - loss: 0.2252 - acc: 0.7968 - val_loss: 0.2153 - val_acc: 0.7962
# Epoch 5/10
# 60000/60000 [==============================] - 1s - loss: 0.2105 - acc: 0.7972 - val_loss: 0.2032 - val_acc: 0.7966
# Epoch 6/10
# 60000/60000 [==============================] - 1s - loss: 0.1998 - acc: 0.7985 - val_loss: 0.1936 - val_acc: 0.7986
# Epoch 7/10
# 60000/60000 [==============================] - 1s - loss: 0.1910 - acc: 0.7999 - val_loss: 0.1857 - val_acc: 0.8004
# Epoch 8/10
# 60000/60000 [==============================] - 1s - loss: 0.1838 - acc: 0.8011 - val_loss: 0.1793 - val_acc: 0.8015
# Epoch 9/10
# 60000/60000 [==============================] - 1s - loss: 0.1778 - acc: 0.8021 - val_loss: 0.1739 - val_acc: 0.8025
# Epoch 10/10
# 60000/60000 [==============================] - 1s - loss: 0.1727 - acc: 0.8030 - val_loss: 0.1690 - val_acc: 0.8030
