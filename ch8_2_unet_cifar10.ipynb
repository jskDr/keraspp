# %%
# %load /home/sjkim/.jupyter/head.py
# %%writefile /home/sjkim/.jupyter/head.py
# %load /home/sjkim/.jupyter/head.py
# %matplotlib inline
# %load_ext autoreload 
# %autoreload 2
from importlib import reload

import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import ex8_1_unet_cifar10
reload(ex8_1_unet_cifar10)
# Out:
# <module 'ex8_1_unet_cifar10' from '/data/data_sjkim/Dropbox/Aspuru-Guzik/python_lab/py3/keraspp/ex8_1_unet_cifar10.py'>

# %%
ex8_1_unet_cifar10.main()
# Out:
# (32, 32, 1) (50000, 32, 32, 1)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 9s - loss: 0.0238 - val_loss: 0.0510
# Epoch 2/10
# 40000/40000 [==============================] - 7s - loss: 0.0137 - val_loss: 0.0415
# Epoch 3/10
# 40000/40000 [==============================] - 7s - loss: 0.0115 - val_loss: 0.0427
# Epoch 4/10
# 40000/40000 [==============================] - 8s - loss: 0.0105 - val_loss: 0.0395
# Epoch 5/10
# 40000/40000 [==============================] - 8s - loss: 0.0099 - val_loss: 0.0214
# Epoch 6/10
# 40000/40000 [==============================] - 8s - loss: 0.0094 - val_loss: 0.0174
# Epoch 7/10
# 40000/40000 [==============================] - 8s - loss: 0.0091 - val_loss: 0.0120
# Epoch 8/10
# 40000/40000 [==============================] - 8s - loss: 0.0089 - val_loss: 0.0090
# Epoch 9/10
# 40000/40000 [==============================] - 8s - loss: 0.0087 - val_loss: 0.0082
# Epoch 10/10
# 40000/40000 [==============================] - 8s - loss: 0.0086 - val_loss: 0.0081
