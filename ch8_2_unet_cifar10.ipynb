# %%
# %load /home/sjkim/.jupyter/head.py
# %%writefile /home/sjkim/.jupyter/head.py
# %load /home/sjkim/.jupyter/head.py
# %matplotlib inline
# %load_ext autoreload 
# %autoreload 2
from importlib import reload

import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import os

# %%
import ex8_1_unet_cifar10

# %%
ex8_1_unet_cifar10.main()
# Out:
# (32, 32, 2) (50000, 32, 32, 2)
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 82s - loss: 0.5841 - val_loss: 0.6107
# Epoch 2/10
# 40000/40000 [==============================] - 12s - loss: 0.5680 - val_loss: 0.5662
# Epoch 3/10
# 40000/40000 [==============================] - 12s - loss: 0.5650 - val_loss: 0.5785
# Epoch 4/10
# 40000/40000 [==============================] - 12s - loss: 0.5633 - val_loss: 0.5673
# Epoch 5/10
# 40000/40000 [==============================] - 12s - loss: 0.5621 - val_loss: 0.5621
# Epoch 6/10
# 40000/40000 [==============================] - 12s - loss: 0.5614 - val_loss: 0.5660
# Epoch 7/10
# 40000/40000 [==============================] - 12s - loss: 0.5609 - val_loss: 0.5619
# Epoch 8/10
# 40000/40000 [==============================] - 12s - loss: 0.5603 - val_loss: 0.5600
# Epoch 9/10
# 40000/40000 [==============================] - 12s - loss: 0.5600 - val_loss: 0.5638
# Epoch 10/10
# 40000/40000 [==============================] - 12s - loss: 0.5596 - val_loss: 0.5592
