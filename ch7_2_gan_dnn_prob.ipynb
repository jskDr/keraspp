# %%
# %load /home/sjkim/.jupyter/head.py
# %%writefile /home/sjkim/.jupyter/head.py
# %matplotlib inline
# %load_ext autoreload 
# %autoreload 2
from importlib import reload
import matplotlib.pyplot as plt
import numpy as np

# %%
from keraspp import gan_dnn_prob
# Out:
# Using TensorFlow backend.

# %%
machine = gan_dnn_prob.Machine(n_batch=1, ni_D=100)
machine.run(n_repeat=200, n_show=200, n_test=100)
# Out:
# Stage 0 (Epoch: 0)
# Mean and Std of Real: (3.9842583454892351, 1.2392254562368177)
# Mean and Std of Gen: (0.01951145, 0.0055207987)
# Stage 1 (Epoch: 200)
# Mean and Std of Real: (3.973695170926967, 1.2414624773415373)
# Mean and Std of Gen: (0.039111968, 0.046260767)
# Stage 2 (Epoch: 400)
# Mean and Std of Real: (4.0204400695335458, 1.2490952531111075)
# Mean and Std of Gen: (-0.056925453, 0.068484783)
# Stage 3 (Epoch: 600)
# Mean and Std of Real: (4.0034142106105444, 1.2481473093195243)
# Mean and Std of Gen: (2.3448124, 0.92431045)
# Stage 4 (Epoch: 800)
# Mean and Std of Real: (4.035975831710032, 1.2504317725339986)
# Mean and Std of Gen: (4.102499, 1.240344)
# Stage 5 (Epoch: 1000)
# Mean and Std of Real: (3.9904870317334797, 1.2449953780299283)
# Mean and Std of Gen: (5.2828646, 1.4764937)
# Stage 6 (Epoch: 1200)
# Mean and Std of Real: (4.0114959444671427, 1.2507787729008464)
# Mean and Std of Gen: (5.6808529, 1.4467325)
# Stage 7 (Epoch: 1400)
# ...
