# %%
# %load /home/sjkim/.jupyter/head.py
# %%writefile /home/sjkim/.jupyter/head.py
# %matplotlib inline
# %load_ext autoreload 
# %autoreload 2
from importlib import reload
import matplotlib.pyplot as plt
import numpy as np

# %%
import ex7_2_gan_cnn_mnist_tf
# Out:
# Using TensorFlow backend.
# <function image_data_format at 0x7f6764e63d90>

# %%
class ARGS:
    pass

args = ARGS()
args.batch_size = 4
args.epochs = 1000
args.output_fold = 'GAN_OUT'
args.input_dim = 10
args.n_train = 8

ex7_2_gan_cnn_mnist_tf.train(args)
# Out:
# Output_fold is GAN_OUT
# Epoch is 0
# Number of batches 2
# Epoch is 1
# Number of batches 2
# Epoch is 2
# Number of batches 2
# Epoch is 3
# Number of batches 2
# Epoch is 4
# Number of batches 2
# Epoch is 5
# Number of batches 2
# Epoch is 6
# Number of batches 2
# Epoch is 7
# Number of batches 2
# Epoch is 8
# Number of batches 2
# Epoch is 9
# Number of batches 2
# Epoch is 10
# Number of batches 2
# Epoch is 11
# Number of batches 2
# Epoch is 12
# Number of batches 2
# Epoch is 13
# Number of batches 2
# Epoch is 14
# Number of batches 2
# Epoch is 15
# Number of batches 2
# Epoch is 16
# Number of batches 2
# Epoch is 17
# Number of batches 2
# Epoch is 18
# Number of batches 2
# Epoch is 19
# Number of batches 2
# Epoch is 20
# Number of batches 2
# Epoch is 21
# Number of batches 2
# Epoch is 22
# Number of batches 2
# Epoch is 23
# Number of batches 2
# Epoch is 24
# Number of batches 2
# Epoch is 25
# Number of batches 2
# Epoch is 26
# Number of batches 2
# Epoch is 27
# Number of batches 2
# Epoch is 28
# Number of batches 2
# Epoch is 29
# Number of batches 2
# Epoch is 30
# Number of batches 2
# Epoch is 31
# Number of batches 2
# Epoch is 32
# Number of batches 2
# Epoch is 33
# Number of batches 2
# Epoch is 34
# Number of batches 2
# Epoch is 35
# Number of batches 2
# Epoch is 36
# Number of batches 2
# Epoch is 37
# Number of batches 2
# Epoch is 38
# Number of batches 2
# Epoch is 39
# Number of batches 2
# Epoch is 40
# Number of batches 2
# Epoch is 41
# Number of batches 2
# Epoch is 42
# Number of batches 2
# Epoch is 43
# Number of batches 2
# Epoch is 44
# Number of batches 2
# Epoch is 45
# Number of batches 2
# Epoch is 46
# Number of batches 2
# Epoch is 47
# Number of batches 2
# Epoch is 48
# Number of batches 2
# Epoch is 49
# Number of batches 2
# Epoch is 50
# Number of batches 2
# Epoch is 51
# Number of batches 2
# Epoch is 52
# Number of batches 2
# Epoch is 53
# Number of batches 2
# Epoch is 54
# Number of batches 2
# Epoch is 55
# Number of batches 2
# Epoch is 56
# Number of batches 2
# Epoch is 57
# Number of batches 2
# Epoch is 58
# Number of batches 2
# Epoch is 59
# Number of batches 2
# Epoch is 60
# Number of batches 2
# Epoch is 61
# Number of batches 2
# Epoch is 62
# Number of batches 2
# Epoch is 63
# Number of batches 2
# Epoch is 64
# Number of batches 2
# Epoch is 65
# Number of batches 2
# Epoch is 66
# Number of batches 2
# Epoch is 67
# Number of batches 2
# Epoch is 68
# Number of batches 2
# Epoch is 69
# Number of batches 2
# Epoch is 70
# Number of batches 2
# Epoch is 71
# Number of batches 2
# Epoch is 72
# Number of batches 2
# Epoch is 73
# Number of batches 2
# Epoch is 74
# Number of batches 2
# Epoch is 75
# Number of batches 2
# Epoch is 76
# Number of batches 2
# Epoch is 77
# Number of batches 2
# Epoch is 78
# Number of batches 2
# Epoch is 79
# Number of batches 2
# Epoch is 80
# Number of batches 2
# Epoch is 81
# Number of batches 2
# Epoch is 82
# Number of batches 2
# Epoch is 83
# Number of batches 2
# Epoch is 84
# Number of batches 2
# Epoch is 85
# Number of batches 2
# Epoch is 86
# Number of batches 2
# Epoch is 87
# Number of batches 2
# Epoch is 88
# Number of batches 2
# Epoch is 89
# Number of batches 2
# Epoch is 90
# Number of batches 2
# Epoch is 91
# Number of batches 2
# Epoch is 92
# Number of batches 2
# Epoch is 93
# Number of batches 2
# Epoch is 94
# Number of batches 2
# Epoch is 95
# Number of batches 2
# Epoch is 96
# Number of batches 2
# Epoch is 97
# Number of batches 2
# Epoch is 98
# Number of batches 2
# Epoch is 99
# Number of batches 2
# Epoch is 100
# Number of batches 2
# Epoch is 101
# Number of batches 2
# Epoch is 102
# Number of batches 2
# Epoch is 103
# Number of batches 2
# Epoch is 104
# Number of batches 2
# Epoch is 105
# Number of batches 2
# Epoch is 106
# Number of batches 2
# Epoch is 107
# Number of batches 2
# Epoch is 108
# Number of batches 2
# Epoch is 109
# Number of batches 2
# Epoch is 110
# Number of batches 2
# Epoch is 111
# Number of batches 2
# Epoch is 112
# Number of batches 2
# Epoch is 113
# Number of batches 2
# Epoch is 114
# Number of batches 2
# Epoch is 115
# Number of batches 2
# Epoch is 116
# Number of batches 2
# Epoch is 117
# Number of batches 2
# Epoch is 118
# Number of batches 2
# Epoch is 119
# Number of batches 2
# Epoch is 120
# Number of batches 2
# Epoch is 121
# Number of batches 2
# Epoch is 122
# Number of batches 2
# Epoch is 123
# Number of batches 2
# Epoch is 124
# Number of batches 2
# Epoch is 125
# Number of batches 2
# Epoch is 126
# Number of batches 2
# Epoch is 127
# Number of batches 2
# Epoch is 128
# Number of batches 2
# Epoch is 129
# Number of batches 2
# Epoch is 130
# Number of batches 2
# Epoch is 131
# Number of batches 2
# Epoch is 132
# Number of batches 2
# Epoch is 133
# Number of batches 2
# Epoch is 134
# Number of batches 2
# Epoch is 135
# Number of batches 2
# Epoch is 136
# Number of batches 2
# Epoch is 137
# Number of batches 2
# Epoch is 138
# Number of batches 2
# Epoch is 139
# Number of batches 2
# Epoch is 140
# Number of batches 2
# Epoch is 141
# Number of batches 2
# Epoch is 142
# Number of batches 2
# Epoch is 143
# Number of batches 2
# Epoch is 144
# Number of batches 2
# Epoch is 145
# Number of batches 2
# Epoch is 146
# Number of batches 2
# Epoch is 147
# Number of batches 2
# Epoch is 148
# Number of batches 2
# Epoch is 149
# Number of batches 2
# Epoch is 150
# Number of batches 2
# Epoch is 151
# Number of batches 2
# Epoch is 152
# Number of batches 2
# Epoch is 153
# Number of batches 2
# Epoch is 154
# Number of batches 2
# Epoch is 155
# Number of batches 2
# Epoch is 156
# Number of batches 2
# Epoch is 157
# Number of batches 2
# Epoch is 158
# Number of batches 2
# Epoch is 159
# Number of batches 2
# Epoch is 160
# Number of batches 2
# Epoch is 161
# Number of batches 2
# Epoch is 162
# Number of batches 2
# Epoch is 163
# Number of batches 2
# Epoch is 164
# Number of batches 2
# Epoch is 165
# Number of batches 2
# Epoch is 166
# Number of batches 2
# Epoch is 167
# Number of batches 2
# Epoch is 168
# Number of batches 2
# Epoch is 169
# Number of batches 2
# Epoch is 170
# Number of batches 2
# Epoch is 171
# Number of batches 2
# Epoch is 172
# Number of batches 2
# Epoch is 173
# Number of batches 2
# Epoch is 174
# Number of batches 2
# Epoch is 175
# Number of batches 2
# Epoch is 176
# Number of batches 2
# Epoch is 177
# Number of batches 2
# Epoch is 178
# Number of batches 2
# Epoch is 179
# Number of batches 2
# Epoch is 180
# Number of batches 2
# Epoch is 181
# Number of batches 2
# Epoch is 182
# Number of batches 2
# Epoch is 183
# Number of batches 2
# Epoch is 184
# Number of batches 2
# Epoch is 185
# Number of batches 2
# Epoch is 186
# Number of batches 2
# Epoch is 187
# Number of batches 2
# Epoch is 188
# Number of batches 2
# Epoch is 189
# Number of batches 2
# Epoch is 190
# Number of batches 2
# Epoch is 191
# Number of batches 2
# Epoch is 192
# Number of batches 2
# Epoch is 193
# Number of batches 2
# Epoch is 194
# Number of batches 2
# Epoch is 195
# Number of batches 2
# Epoch is 196
# Number of batches 2
# Epoch is 197
# Number of batches 2
# Epoch is 198
# Number of batches 2
# Epoch is 199
# Number of batches 2
# Epoch is 200
# Number of batches 2
# Epoch is 201
# Number of batches 2
# Epoch is 202
# Number of batches 2
# Epoch is 203
# Number of batches 2
# Epoch is 204
# Number of batches 2
# Epoch is 205
# Number of batches 2
# Epoch is 206
# Number of batches 2
# Epoch is 207
# Number of batches 2
# Epoch is 208
# Number of batches 2
# Epoch is 209
# Number of batches 2
# Epoch is 210
# Number of batches 2
# Epoch is 211
# Number of batches 2
# Epoch is 212
# Number of batches 2
# Epoch is 213
# Number of batches 2
# Epoch is 214
# Number of batches 2
# Epoch is 215
# Number of batches 2
# Epoch is 216
# Number of batches 2
# Epoch is 217
# Number of batches 2
# Epoch is 218
# Number of batches 2
# Epoch is 219
# Number of batches 2
# Epoch is 220
# Number of batches 2
# Epoch is 221
# Number of batches 2
# Epoch is 222
# Number of batches 2
# Epoch is 223
# Number of batches 2
# Epoch is 224
# Number of batches 2
# Epoch is 225
# Number of batches 2
# Epoch is 226
# Number of batches 2
# Epoch is 227
# Number of batches 2
# Epoch is 228
# Number of batches 2
# Epoch is 229
# Number of batches 2
# Epoch is 230
# Number of batches 2
# Epoch is 231
# Number of batches 2
# Epoch is 232
# Number of batches 2
# Epoch is 233
# Number of batches 2
# Epoch is 234
# Number of batches 2
# Epoch is 235
# Number of batches 2
# Epoch is 236
# Number of batches 2
# Epoch is 237
# Number of batches 2
# Epoch is 238
# Number of batches 2
# Epoch is 239
# Number of batches 2
# Epoch is 240
# Number of batches 2
# Epoch is 241
# Number of batches 2
# Epoch is 242
# Number of batches 2
# Epoch is 243
# Number of batches 2
# Epoch is 244
# Number of batches 2
# Epoch is 245
# Number of batches 2
# Epoch is 246
# Number of batches 2
# Epoch is 247
# Number of batches 2
# Epoch is 248
# Number of batches 2
# Epoch is 249
# Number of batches 2
# Epoch is 250
# Number of batches 2
# Epoch is 251
# Number of batches 2
# Epoch is 252
# Number of batches 2
# Epoch is 253
# Number of batches 2
# Epoch is 254
# Number of batches 2
# Epoch is 255
# Number of batches 2
# Epoch is 256
# Number of batches 2
# Epoch is 257
# Number of batches 2
# Epoch is 258
# Number of batches 2
# Epoch is 259
# Number of batches 2
# Epoch is 260
# Number of batches 2
# Epoch is 261
# Number of batches 2
# Epoch is 262
# Number of batches 2
# Epoch is 263
# Number of batches 2
# Epoch is 264
# Number of batches 2
# Epoch is 265
# Number of batches 2
# Epoch is 266
# Number of batches 2
# Epoch is 267
# Number of batches 2
# Epoch is 268
# Number of batches 2
# Epoch is 269
# Number of batches 2
# Epoch is 270
# Number of batches 2
# Epoch is 271
# Number of batches 2
# Epoch is 272
# Number of batches 2
# Epoch is 273
# Number of batches 2
# Epoch is 274
# Number of batches 2
# Epoch is 275
# Number of batches 2
# Epoch is 276
# Number of batches 2
# Epoch is 277
# Number of batches 2
# Epoch is 278
# Number of batches 2
# Epoch is 279
# Number of batches 2
# Epoch is 280
# Number of batches 2
# Epoch is 281
# Number of batches 2
# Epoch is 282
# Number of batches 2
# Epoch is 283
# Number of batches 2
# Epoch is 284
# Number of batches 2
# Epoch is 285
# Number of batches 2
# Epoch is 286
# Number of batches 2
# Epoch is 287
# Number of batches 2
# Epoch is 288
# Number of batches 2
# Epoch is 289
# Number of batches 2
# Epoch is 290
# Number of batches 2
# Epoch is 291
# Number of batches 2
# Epoch is 292
# Number of batches 2
# Epoch is 293
# Number of batches 2
# Epoch is 294
# Number of batches 2
# Epoch is 295
# Number of batches 2
# Epoch is 296
# Number of batches 2
# Epoch is 297
# Number of batches 2
# Epoch is 298
# Number of batches 2
# Epoch is 299
# Number of batches 2
# Epoch is 300
# Number of batches 2
# Epoch is 301
# Number of batches 2
# Epoch is 302
# Number of batches 2
# Epoch is 303
# Number of batches 2
# Epoch is 304
# Number of batches 2
# Epoch is 305
# Number of batches 2
# Epoch is 306
# Number of batches 2
# Epoch is 307
# Number of batches 2
# Epoch is 308
# Number of batches 2
# Epoch is 309
# Number of batches 2
# Epoch is 310
# Number of batches 2
# Epoch is 311
# Number of batches 2
# Epoch is 312
# Number of batches 2
# Epoch is 313
# Number of batches 2
# Epoch is 314
# Number of batches 2
# Epoch is 315
# Number of batches 2
# Epoch is 316
# Number of batches 2
# Epoch is 317
# Number of batches 2
# Epoch is 318
# Number of batches 2
# Epoch is 319
# Number of batches 2
# Epoch is 320
# Number of batches 2
# Epoch is 321
# Number of batches 2
# Epoch is 322
# Number of batches 2
# Epoch is 323
# Number of batches 2
# Epoch is 324
# Number of batches 2
# Epoch is 325
# Number of batches 2
# Epoch is 326
# Number of batches 2
# Epoch is 327
# Number of batches 2
# Epoch is 328
# Number of batches 2
# Epoch is 329
# Number of batches 2
# Epoch is 330
# Number of batches 2
# Epoch is 331
# Number of batches 2
# Epoch is 332
# Number of batches 2
# Epoch is 333
# Number of batches 2
# Epoch is 334
# Number of batches 2
# Epoch is 335
# Number of batches 2
# Epoch is 336
# Number of batches 2
# Epoch is 337
# Number of batches 2
# Epoch is 338
# Number of batches 2
# Epoch is 339
# Number of batches 2
# Epoch is 340
# Number of batches 2
# Epoch is 341
# Number of batches 2
# Epoch is 342
# Number of batches 2
# Epoch is 343
# Number of batches 2
# Epoch is 344
# Number of batches 2
# Epoch is 345
# Number of batches 2
# Epoch is 346
# Number of batches 2
# Epoch is 347
# Number of batches 2
# Epoch is 348
# Number of batches 2
# Epoch is 349
# Number of batches 2
# Epoch is 350
# Number of batches 2
# Epoch is 351
# Number of batches 2
# Epoch is 352
# Number of batches 2
# Epoch is 353
# Number of batches 2
# Epoch is 354
# Number of batches 2
# Epoch is 355
# Number of batches 2
# Epoch is 356
# Number of batches 2
# Epoch is 357
# Number of batches 2
# Epoch is 358
# Number of batches 2
# Epoch is 359
# Number of batches 2
# Epoch is 360
# Number of batches 2
# Epoch is 361
# Number of batches 2
# Epoch is 362
# Number of batches 2
# Epoch is 363
# Number of batches 2
# Epoch is 364
# Number of batches 2
# Epoch is 365
# Number of batches 2
# Epoch is 366
# Number of batches 2
# Epoch is 367
# Number of batches 2
# Epoch is 368
# Number of batches 2
# Epoch is 369
# Number of batches 2
# Epoch is 370
# Number of batches 2
# Epoch is 371
# Number of batches 2
# Epoch is 372
# Number of batches 2
# Epoch is 373
# Number of batches 2
# Epoch is 374
# Number of batches 2
# Epoch is 375
# Number of batches 2
# Epoch is 376
# Number of batches 2
# Epoch is 377
# Number of batches 2
# Epoch is 378
# Number of batches 2
# Epoch is 379
# Number of batches 2
# Epoch is 380
# Number of batches 2
# Epoch is 381
# Number of batches 2
# Epoch is 382
# Number of batches 2
# Epoch is 383
# Number of batches 2
# Epoch is 384
# Number of batches 2
# Epoch is 385
# Number of batches 2
# Epoch is 386
# Number of batches 2
# Epoch is 387
# Number of batches 2
# Epoch is 388
# Number of batches 2
# Epoch is 389
# Number of batches 2
# Epoch is 390
# Number of batches 2
# Epoch is 391
# Number of batches 2
# Epoch is 392
# Number of batches 2
# Epoch is 393
# Number of batches 2
# Epoch is 394
# Number of batches 2
# Epoch is 395
# Number of batches 2
# Epoch is 396
# Number of batches 2
# Epoch is 397
# Number of batches 2
# Epoch is 398
# Number of batches 2
# Epoch is 399
# Number of batches 2
# Epoch is 400
# Number of batches 2
# Epoch is 401
# Number of batches 2
# Epoch is 402
# Number of batches 2
# Epoch is 403
# Number of batches 2
# Epoch is 404
# Number of batches 2
# Epoch is 405
# Number of batches 2
# Epoch is 406
# Number of batches 2
# Epoch is 407
# Number of batches 2
# Epoch is 408
# Number of batches 2
# Epoch is 409
# Number of batches 2
# Epoch is 410
# Number of batches 2
# Epoch is 411
# Number of batches 2
# Epoch is 412
# Number of batches 2
# Epoch is 413
# Number of batches 2
# Epoch is 414
# Number of batches 2
# Epoch is 415
# Number of batches 2
# Epoch is 416
# Number of batches 2
# Epoch is 417
# Number of batches 2
# Epoch is 418
# Number of batches 2
# Epoch is 419
# Number of batches 2
# Epoch is 420
# Number of batches 2
# Epoch is 421
# Number of batches 2
# Epoch is 422
# Number of batches 2
# Epoch is 423
# Number of batches 2
# Epoch is 424
# Number of batches 2
# Epoch is 425
# Number of batches 2
# Epoch is 426
# Number of batches 2
# Epoch is 427
# Number of batches 2
# Epoch is 428
# Number of batches 2
# Epoch is 429
# Number of batches 2
# Epoch is 430
# Number of batches 2
# Epoch is 431
# Number of batches 2
# Epoch is 432
# Number of batches 2
# Epoch is 433
# Number of batches 2
# Epoch is 434
# Number of batches 2
# Epoch is 435
# Number of batches 2
# Epoch is 436
# Number of batches 2
# Epoch is 437
# Number of batches 2
# Epoch is 438
# Number of batches 2
# Epoch is 439
# Number of batches 2
# Epoch is 440
# Number of batches 2
# Epoch is 441
# Number of batches 2
# Epoch is 442
# Number of batches 2
# Epoch is 443
# Number of batches 2
# Epoch is 444
# Number of batches 2
# Epoch is 445
# Number of batches 2
# Epoch is 446
# Number of batches 2
# Epoch is 447
# Number of batches 2
# Epoch is 448
# Number of batches 2
# Epoch is 449
# Number of batches 2
# Epoch is 450
# Number of batches 2
# Epoch is 451
# Number of batches 2
# Epoch is 452
# Number of batches 2
# Epoch is 453
# Number of batches 2
# Epoch is 454
# Number of batches 2
# Epoch is 455
# Number of batches 2
# Epoch is 456
# Number of batches 2
# Epoch is 457
# Number of batches 2
# Epoch is 458
# Number of batches 2
# Epoch is 459
# Number of batches 2
# Epoch is 460
# Number of batches 2
# Epoch is 461
# Number of batches 2
# Epoch is 462
# Number of batches 2
# Epoch is 463
# Number of batches 2
# Epoch is 464
# Number of batches 2
# Epoch is 465
# Number of batches 2
# Epoch is 466
# Number of batches 2
# Epoch is 467
# Number of batches 2
# Epoch is 468
# Number of batches 2
# Epoch is 469
# Number of batches 2
# Epoch is 470
# Number of batches 2
# Epoch is 471
# Number of batches 2
# Epoch is 472
# Number of batches 2
# Epoch is 473
# Number of batches 2
# Epoch is 474
# Number of batches 2
# Epoch is 475
# Number of batches 2
# Epoch is 476
# Number of batches 2
# Epoch is 477
# Number of batches 2
# Epoch is 478
# Number of batches 2
# Epoch is 479
# Number of batches 2
# Epoch is 480
# Number of batches 2
# Epoch is 481
# Number of batches 2
# Epoch is 482
# Number of batches 2
# Epoch is 483
# Number of batches 2
# Epoch is 484
# Number of batches 2
# Epoch is 485
# Number of batches 2
# Epoch is 486
# Number of batches 2
# Epoch is 487
# Number of batches 2
# Epoch is 488
# Number of batches 2
# Epoch is 489
# Number of batches 2
# Epoch is 490
# Number of batches 2
# Epoch is 491
# Number of batches 2
# Epoch is 492
# Number of batches 2
# Epoch is 493
# Number of batches 2
# Epoch is 494
# Number of batches 2
# Epoch is 495
# Number of batches 2
# Epoch is 496
# Number of batches 2
# Epoch is 497
# Number of batches 2
# Epoch is 498
# Number of batches 2
# Epoch is 499
# Number of batches 2
# Epoch is 500
# Number of batches 2
# Epoch is 501
# Number of batches 2
# Epoch is 502
# Number of batches 2
# Epoch is 503
# Number of batches 2
# Epoch is 504
# Number of batches 2
# Epoch is 505
# Number of batches 2
# Epoch is 506
# Number of batches 2
# Epoch is 507
# Number of batches 2
# Epoch is 508
# Number of batches 2
# Epoch is 509
# Number of batches 2
# Epoch is 510
# Number of batches 2
# Epoch is 511
# Number of batches 2
# Epoch is 512
# Number of batches 2
# Epoch is 513
# Number of batches 2
# Epoch is 514
# Number of batches 2
# Epoch is 515
# Number of batches 2
# Epoch is 516
# Number of batches 2
# Epoch is 517
# Number of batches 2
# Epoch is 518
# Number of batches 2
# Epoch is 519
# Number of batches 2
# Epoch is 520
# Number of batches 2
# Epoch is 521
# Number of batches 2
# Epoch is 522
# Number of batches 2
# Epoch is 523
# Number of batches 2
# Epoch is 524
# Number of batches 2
# Epoch is 525
# Number of batches 2
# Epoch is 526
# Number of batches 2
# Epoch is 527
# Number of batches 2
# Epoch is 528
# Number of batches 2
# Epoch is 529
# Number of batches 2
# Epoch is 530
# Number of batches 2
# Epoch is 531
# Number of batches 2
# Epoch is 532
# Number of batches 2
# Epoch is 533
# Number of batches 2
# Epoch is 534
# Number of batches 2
# Epoch is 535
# Number of batches 2
# Epoch is 536
# Number of batches 2
# Epoch is 537
# Number of batches 2
# Epoch is 538
# Number of batches 2
# Epoch is 539
# Number of batches 2
# Epoch is 540
# Number of batches 2
# Epoch is 541
# Number of batches 2
# Epoch is 542
# Number of batches 2
# Epoch is 543
# Number of batches 2
# Epoch is 544
# Number of batches 2
# Epoch is 545
# Number of batches 2
# Epoch is 546
# Number of batches 2
# Epoch is 547
# Number of batches 2
# Epoch is 548
# Number of batches 2
# Epoch is 549
# Number of batches 2
# Epoch is 550
# Number of batches 2
# Epoch is 551
# Number of batches 2
# Epoch is 552
# Number of batches 2
# Epoch is 553
# Number of batches 2
# Epoch is 554
# Number of batches 2
# Epoch is 555
# Number of batches 2
# Epoch is 556
# Number of batches 2
# Epoch is 557
# Number of batches 2
# Epoch is 558
# Number of batches 2
# Epoch is 559
# Number of batches 2
# Epoch is 560
# Number of batches 2
# Epoch is 561
# Number of batches 2
# Epoch is 562
# Number of batches 2
# Epoch is 563
# Number of batches 2
# Epoch is 564
# Number of batches 2
# Epoch is 565
# Number of batches 2
# Epoch is 566
# Number of batches 2
# Epoch is 567
# Number of batches 2
# Epoch is 568
# Number of batches 2
# Epoch is 569
# Number of batches 2
# Epoch is 570
# Number of batches 2
# Epoch is 571
# Number of batches 2
# Epoch is 572
# Number of batches 2
# Epoch is 573
# Number of batches 2
# Epoch is 574
# Number of batches 2
# Epoch is 575
# Number of batches 2
# Epoch is 576
# Number of batches 2
# Epoch is 577
# Number of batches 2
# Epoch is 578
# Number of batches 2
# Epoch is 579
# Number of batches 2
# Epoch is 580
# Number of batches 2
# Epoch is 581
# Number of batches 2
# Epoch is 582
# Number of batches 2
# Epoch is 583
# Number of batches 2
# Epoch is 584
# Number of batches 2
# Epoch is 585
# Number of batches 2
# Epoch is 586
# Number of batches 2
# Epoch is 587
# Number of batches 2
# Epoch is 588
# Number of batches 2
# Epoch is 589
# Number of batches 2
# Epoch is 590
# Number of batches 2
# Epoch is 591
# Number of batches 2
# Epoch is 592
# Number of batches 2
# Epoch is 593
# Number of batches 2
# Epoch is 594
# Number of batches 2
# Epoch is 595
# Number of batches 2
# Epoch is 596
# Number of batches 2
# Epoch is 597
# Number of batches 2
# Epoch is 598
# Number of batches 2
# Epoch is 599
# Number of batches 2
# Epoch is 600
# Number of batches 2
# Epoch is 601
# Number of batches 2
# Epoch is 602
# Number of batches 2
# Epoch is 603
# Number of batches 2
# Epoch is 604
# Number of batches 2
# Epoch is 605
# Number of batches 2
# Epoch is 606
# Number of batches 2
# Epoch is 607
# Number of batches 2
# Epoch is 608
# Number of batches 2
# Epoch is 609
# Number of batches 2
# Epoch is 610
# Number of batches 2
# Epoch is 611
# Number of batches 2
# Epoch is 612
# Number of batches 2
# Epoch is 613
# Number of batches 2
# Epoch is 614
# Number of batches 2
# Epoch is 615
# Number of batches 2
# Epoch is 616
# Number of batches 2
# Epoch is 617
# Number of batches 2
# Epoch is 618
# Number of batches 2
# Epoch is 619
# Number of batches 2
# Epoch is 620
# Number of batches 2
# Epoch is 621
# Number of batches 2
# Epoch is 622
# Number of batches 2
# Epoch is 623
# Number of batches 2
# Epoch is 624
# Number of batches 2
# Epoch is 625
# Number of batches 2
# Epoch is 626
# Number of batches 2
# Epoch is 627
# Number of batches 2
# Epoch is 628
# Number of batches 2
# Epoch is 629
# Number of batches 2
# Epoch is 630
# Number of batches 2
# Epoch is 631
# Number of batches 2
# Epoch is 632
# Number of batches 2
# Epoch is 633
# Number of batches 2
# Epoch is 634
# Number of batches 2
# Epoch is 635
# Number of batches 2
# Epoch is 636
# Number of batches 2
# Epoch is 637
# Number of batches 2
# Epoch is 638
# Number of batches 2
# Epoch is 639
# Number of batches 2
# Epoch is 640
# Number of batches 2
# Epoch is 641
# Number of batches 2
# Epoch is 642
# Number of batches 2
# Epoch is 643
# Number of batches 2
# Epoch is 644
# Number of batches 2
# Epoch is 645
# Number of batches 2
# Epoch is 646
# Number of batches 2
# Epoch is 647
# Number of batches 2
# Epoch is 648
# Number of batches 2
# Epoch is 649
# Number of batches 2
# Epoch is 650
# Number of batches 2
# Epoch is 651
# Number of batches 2
# Epoch is 652
# Number of batches 2
# Epoch is 653
# Number of batches 2
# Epoch is 654
# Number of batches 2
# Epoch is 655
# Number of batches 2
# Epoch is 656
# Number of batches 2
# Epoch is 657
# Number of batches 2
# Epoch is 658
# Number of batches 2
# Epoch is 659
# Number of batches 2
# Epoch is 660
# Number of batches 2
# Epoch is 661
# Number of batches 2
# Epoch is 662
# Number of batches 2
# Epoch is 663
# Number of batches 2
# Epoch is 664
# Number of batches 2
# Epoch is 665
# Number of batches 2
# Epoch is 666
# Number of batches 2
# Epoch is 667
# Number of batches 2
# Epoch is 668
# Number of batches 2
# Epoch is 669
# Number of batches 2
# Epoch is 670
# Number of batches 2
# Epoch is 671
# Number of batches 2
# Epoch is 672
# Number of batches 2
# Epoch is 673
# Number of batches 2
# Epoch is 674
# Number of batches 2
# Epoch is 675
# Number of batches 2
# Epoch is 676
# Number of batches 2
# Epoch is 677
# Number of batches 2
# Epoch is 678
# Number of batches 2
# Epoch is 679
# Number of batches 2
# Epoch is 680
# Number of batches 2
# Epoch is 681
# Number of batches 2
# Epoch is 682
# Number of batches 2
# Epoch is 683
# Number of batches 2
# Epoch is 684
# Number of batches 2
# Epoch is 685
# Number of batches 2
# Epoch is 686
# Number of batches 2
# Epoch is 687
# Number of batches 2
# Epoch is 688
# Number of batches 2
# Epoch is 689
# Number of batches 2
# Epoch is 690
# Number of batches 2
# Epoch is 691
# Number of batches 2
# Epoch is 692
# Number of batches 2
# Epoch is 693
# Number of batches 2
# Epoch is 694
# Number of batches 2
# Epoch is 695
# Number of batches 2
# Epoch is 696
# Number of batches 2
# Epoch is 697
# Number of batches 2
# Epoch is 698
# Number of batches 2
# Epoch is 699
# Number of batches 2
# Epoch is 700
# Number of batches 2
# Epoch is 701
# Number of batches 2
# Epoch is 702
# Number of batches 2
# Epoch is 703
# Number of batches 2
# Epoch is 704
# Number of batches 2
# Epoch is 705
# Number of batches 2
# Epoch is 706
# Number of batches 2
# Epoch is 707
# Number of batches 2
# Epoch is 708
# Number of batches 2
# Epoch is 709
# Number of batches 2
# Epoch is 710
# Number of batches 2
# Epoch is 711
# Number of batches 2
# Epoch is 712
# Number of batches 2
# Epoch is 713
# Number of batches 2
# Epoch is 714
# Number of batches 2
# Epoch is 715
# Number of batches 2
# Epoch is 716
# Number of batches 2
# Epoch is 717
# Number of batches 2
# Epoch is 718
# Number of batches 2
# Epoch is 719
# Number of batches 2
# Epoch is 720
# Number of batches 2
# Epoch is 721
# Number of batches 2
# Epoch is 722
# Number of batches 2
# Epoch is 723
# Number of batches 2
# Epoch is 724
# Number of batches 2
# Epoch is 725
# Number of batches 2
# Epoch is 726
# Number of batches 2
# Epoch is 727
# Number of batches 2
# Epoch is 728
# Number of batches 2
# Epoch is 729
# Number of batches 2
# Epoch is 730
# Number of batches 2
# Epoch is 731
# Number of batches 2
# Epoch is 732
# Number of batches 2
# Epoch is 733
# Number of batches 2
# Epoch is 734
# Number of batches 2
# Epoch is 735
# Number of batches 2
# Epoch is 736
# Number of batches 2
# Epoch is 737
# Number of batches 2
# Epoch is 738
# Number of batches 2
# Epoch is 739
# Number of batches 2
# Epoch is 740
# Number of batches 2
# Epoch is 741
# Number of batches 2
# Epoch is 742
# Number of batches 2
# Epoch is 743
# Number of batches 2
# Epoch is 744
# Number of batches 2
# Epoch is 745
# Number of batches 2
# Epoch is 746
# Number of batches 2
# Epoch is 747
# Number of batches 2
# Epoch is 748
# Number of batches 2
# Epoch is 749
# Number of batches 2
# Epoch is 750
# Number of batches 2
# Epoch is 751
# Number of batches 2
# Epoch is 752
# Number of batches 2
# Epoch is 753
# Number of batches 2
# Epoch is 754
# Number of batches 2
# Epoch is 755
# Number of batches 2
# Epoch is 756
# Number of batches 2
# Epoch is 757
# Number of batches 2
# Epoch is 758
# Number of batches 2
# Epoch is 759
# Number of batches 2
# Epoch is 760
# Number of batches 2
# Epoch is 761
# Number of batches 2
# Epoch is 762
# Number of batches 2
# Epoch is 763
# Number of batches 2
# Epoch is 764
# Number of batches 2
# Epoch is 765
# Number of batches 2
# Epoch is 766
# Number of batches 2
# Epoch is 767
# Number of batches 2
# Epoch is 768
# Number of batches 2
# Epoch is 769
# Number of batches 2
# Epoch is 770
# Number of batches 2
# Epoch is 771
# Number of batches 2
# Epoch is 772
# Number of batches 2
# Epoch is 773
# Number of batches 2
# Epoch is 774
# Number of batches 2
# Epoch is 775
# Number of batches 2
# Epoch is 776
# Number of batches 2
# Epoch is 777
# Number of batches 2
# Epoch is 778
# Number of batches 2
# Epoch is 779
# Number of batches 2
# Epoch is 780
# Number of batches 2
# Epoch is 781
# Number of batches 2
# Epoch is 782
# Number of batches 2
# Epoch is 783
# Number of batches 2
# Epoch is 784
# Number of batches 2
# Epoch is 785
# Number of batches 2
# Epoch is 786
# Number of batches 2
# Epoch is 787
# Number of batches 2
# Epoch is 788
# Number of batches 2
# Epoch is 789
# Number of batches 2
# Epoch is 790
# Number of batches 2
# Epoch is 791
# Number of batches 2
# Epoch is 792
# Number of batches 2
# Epoch is 793
# Number of batches 2
# Epoch is 794
# Number of batches 2
# Epoch is 795
# Number of batches 2
# Epoch is 796
# Number of batches 2
# Epoch is 797
# Number of batches 2
# Epoch is 798
# Number of batches 2
# Epoch is 799
# Number of batches 2
# Epoch is 800
# Number of batches 2
# Epoch is 801
# Number of batches 2
# Epoch is 802
# Number of batches 2
# Epoch is 803
# Number of batches 2
# Epoch is 804
# Number of batches 2
# Epoch is 805
# Number of batches 2
# Epoch is 806
# Number of batches 2
# Epoch is 807
# Number of batches 2
# Epoch is 808
# Number of batches 2
# Epoch is 809
# Number of batches 2
# Epoch is 810
# Number of batches 2
# Epoch is 811
# Number of batches 2
# Epoch is 812
# Number of batches 2
# Epoch is 813
# Number of batches 2
# Epoch is 814
# Number of batches 2
# Epoch is 815
# Number of batches 2
# Epoch is 816
# Number of batches 2
# Epoch is 817
# Number of batches 2
# Epoch is 818
# Number of batches 2
# Epoch is 819
# Number of batches 2
# Epoch is 820
# Number of batches 2
# Epoch is 821
# Number of batches 2
# Epoch is 822
# Number of batches 2
# Epoch is 823
# Number of batches 2
# Epoch is 824
# Number of batches 2
# Epoch is 825
# Number of batches 2
# Epoch is 826
# Number of batches 2
# Epoch is 827
# Number of batches 2
# Epoch is 828
# Number of batches 2
# Epoch is 829
# Number of batches 2
# Epoch is 830
# Number of batches 2
# Epoch is 831
# Number of batches 2
# Epoch is 832
# Number of batches 2
# Epoch is 833
# Number of batches 2
# Epoch is 834
# Number of batches 2
# Epoch is 835
# Number of batches 2
# Epoch is 836
# Number of batches 2
# Epoch is 837
# Number of batches 2
# Epoch is 838
# Number of batches 2
# Epoch is 839
# Number of batches 2
# Epoch is 840
# Number of batches 2
# Epoch is 841
# Number of batches 2
# Epoch is 842
# Number of batches 2
# Epoch is 843
# Number of batches 2
# Epoch is 844
# Number of batches 2
# Epoch is 845
# Number of batches 2
# Epoch is 846
# Number of batches 2
# Epoch is 847
# Number of batches 2
# Epoch is 848
# Number of batches 2
# Epoch is 849
# Number of batches 2
# Epoch is 850
# Number of batches 2
# Epoch is 851
# Number of batches 2
# Epoch is 852
# Number of batches 2
# Epoch is 853
# Number of batches 2
# Epoch is 854
# Number of batches 2
# Epoch is 855
# Number of batches 2
# Epoch is 856
# Number of batches 2
# Epoch is 857
# Number of batches 2
# Epoch is 858
# Number of batches 2
# Epoch is 859
# Number of batches 2
# Epoch is 860
# Number of batches 2
# Epoch is 861
# Number of batches 2
# Epoch is 862
# Number of batches 2
# Epoch is 863
# Number of batches 2
# Epoch is 864
# Number of batches 2
# Epoch is 865
# Number of batches 2
# Epoch is 866
# Number of batches 2
# Epoch is 867
# Number of batches 2
# Epoch is 868
# Number of batches 2
# Epoch is 869
# Number of batches 2
# Epoch is 870
# Number of batches 2
# Epoch is 871
# Number of batches 2
# Epoch is 872
# Number of batches 2
# Epoch is 873
# Number of batches 2
# Epoch is 874
# Number of batches 2
# Epoch is 875
# Number of batches 2
# Epoch is 876
# Number of batches 2
# Epoch is 877
# Number of batches 2
# Epoch is 878
# Number of batches 2
# Epoch is 879
# Number of batches 2
# Epoch is 880
# Number of batches 2
# Epoch is 881
# Number of batches 2
# Epoch is 882
# Number of batches 2
# Epoch is 883
# Number of batches 2
# Epoch is 884
# Number of batches 2
# Epoch is 885
# Number of batches 2
# Epoch is 886
# Number of batches 2
# Epoch is 887
# Number of batches 2
# Epoch is 888
# Number of batches 2
# Epoch is 889
# Number of batches 2
# Epoch is 890
# Number of batches 2
# Epoch is 891
# Number of batches 2
# Epoch is 892
# Number of batches 2
# Epoch is 893
# Number of batches 2
# Epoch is 894
# Number of batches 2
# Epoch is 895
# Number of batches 2
# Epoch is 896
# Number of batches 2
# Epoch is 897
# Number of batches 2
# Epoch is 898
# Number of batches 2
# Epoch is 899
# Number of batches 2
# Epoch is 900
# Number of batches 2
# Epoch is 901
# Number of batches 2
# Epoch is 902
# Number of batches 2
# Epoch is 903
# Number of batches 2
# Epoch is 904
# Number of batches 2
# Epoch is 905
# Number of batches 2
# Epoch is 906
# Number of batches 2
# Epoch is 907
# Number of batches 2
# Epoch is 908
# Number of batches 2
# Epoch is 909
# Number of batches 2
# Epoch is 910
# Number of batches 2
# Epoch is 911
# Number of batches 2
# Epoch is 912
# Number of batches 2
# Epoch is 913
# Number of batches 2
# Epoch is 914
# Number of batches 2
# Epoch is 915
# Number of batches 2
# Epoch is 916
# Number of batches 2
# Epoch is 917
# Number of batches 2
# Epoch is 918
# Number of batches 2
# Epoch is 919
# Number of batches 2
# Epoch is 920
# Number of batches 2
# Epoch is 921
# Number of batches 2
# Epoch is 922
# Number of batches 2
# Epoch is 923
# Number of batches 2
# Epoch is 924
# Number of batches 2
# Epoch is 925
# Number of batches 2
# Epoch is 926
# Number of batches 2
# Epoch is 927
# Number of batches 2
# Epoch is 928
# Number of batches 2
# Epoch is 929
# Number of batches 2
# Epoch is 930
# Number of batches 2
# Epoch is 931
# Number of batches 2
# Epoch is 932
# Number of batches 2
# Epoch is 933
# Number of batches 2
# Epoch is 934
# Number of batches 2
# Epoch is 935
# Number of batches 2
# Epoch is 936
# Number of batches 2
# Epoch is 937
# Number of batches 2
# Epoch is 938
# Number of batches 2
# Epoch is 939
# Number of batches 2
# Epoch is 940
# Number of batches 2
# Epoch is 941
# Number of batches 2
# Epoch is 942
# Number of batches 2
# Epoch is 943
# Number of batches 2
# Epoch is 944
# Number of batches 2
# Epoch is 945
# Number of batches 2
# Epoch is 946
# Number of batches 2
# Epoch is 947
# Number of batches 2
# Epoch is 948
# Number of batches 2
# Epoch is 949
# Number of batches 2
# Epoch is 950
# Number of batches 2
# Epoch is 951
# Number of batches 2
# Epoch is 952
# Number of batches 2
# Epoch is 953
# Number of batches 2
# Epoch is 954
# Number of batches 2
# Epoch is 955
# Number of batches 2
# Epoch is 956
# Number of batches 2
# Epoch is 957
# Number of batches 2
# Epoch is 958
# Number of batches 2
# Epoch is 959
# Number of batches 2
# Epoch is 960
# Number of batches 2
# Epoch is 961
# Number of batches 2
# Epoch is 962
# Number of batches 2
# Epoch is 963
# Number of batches 2
# Epoch is 964
# Number of batches 2
# Epoch is 965
# Number of batches 2
# Epoch is 966
# Number of batches 2
# Epoch is 967
# Number of batches 2
# Epoch is 968
# Number of batches 2
# Epoch is 969
# Number of batches 2
# Epoch is 970
# Number of batches 2
# Epoch is 971
# Number of batches 2
# Epoch is 972
# Number of batches 2
# Epoch is 973
# Number of batches 2
# Epoch is 974
# Number of batches 2
# Epoch is 975
# Number of batches 2
# Epoch is 976
# Number of batches 2
# Epoch is 977
# Number of batches 2
# Epoch is 978
# Number of batches 2
# Epoch is 979
# Number of batches 2
# Epoch is 980
# Number of batches 2
# Epoch is 981
# Number of batches 2
# Epoch is 982
# Number of batches 2
# Epoch is 983
# Number of batches 2
# Epoch is 984
# Number of batches 2
# Epoch is 985
# Number of batches 2
# Epoch is 986
# Number of batches 2
# Epoch is 987
# Number of batches 2
# Epoch is 988
# Number of batches 2
# Epoch is 989
# Number of batches 2
# Epoch is 990
# Number of batches 2
# Epoch is 991
# Number of batches 2
# Epoch is 992
# Number of batches 2
# Epoch is 993
# Number of batches 2
# Epoch is 994
# Number of batches 2
# Epoch is 995
# Number of batches 2
# Epoch is 996
# Number of batches 2
# Epoch is 997
# Number of batches 2
# Epoch is 998
# Number of batches 2
# Epoch is 999
# Number of batches 2
