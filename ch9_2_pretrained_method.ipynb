# %%
# %matplotlib inline

# %%
import ex9_2_pretarined_method
# Out:
# Using TensorFlow backend.

# %%
m = ex9_2_pretarined_method.Machine()
m.run()
# Out:
# (800, 32, 32, 3) (800, 1)
# X_train shape: (800, 32, 32, 3)
# 800 train samples
# 200 test samples
# (800, 32, 32, 3)
# Epoch 1/100
# 10/10 [==============================] - 44s - loss: 12.3800 - acc: 0.1115 - val_loss: 10.0408 - val_acc: 0.1700
# Epoch 2/100
# 10/10 [==============================] - 0s - loss: 11.4158 - acc: 0.1603 - val_loss: 9.0498 - val_acc: 0.2500
# Epoch 3/100
# 10/10 [==============================] - 0s - loss: 10.6919 - acc: 0.1862 - val_loss: 8.2579 - val_acc: 0.2800
# Epoch 4/100
# 10/10 [==============================] - 0s - loss: 9.6991 - acc: 0.2256 - val_loss: 7.2720 - val_acc: 0.3150
# Epoch 5/100
# 10/10 [==============================] - 0s - loss: 9.4757 - acc: 0.2375 - val_loss: 6.9897 - val_acc: 0.3300
# Epoch 6/100
# 10/10 [==============================] - 0s - loss: 8.7235 - acc: 0.2680 - val_loss: 6.4410 - val_acc: 0.3900
# Epoch 7/100
# ...
