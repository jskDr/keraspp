# %%
# %load /home/sjkim/.jupyter/head.py
# %load /home/sjkim/.jupyter/head.py
# %%writefile /home/sjkim/.jupyter/head.py
# %load /home/sjkim/.jupyter/head.py
# %matplotlib inline
# %load_ext autoreload 
# %autoreload 2
from importlib import reload

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# seaborn
import seaborn as sns
sns.set( style = 'white', font_scale = 1.7)
sns.set_style('ticks')
plt.rcParams['savefig.dpi'] = 200

# font for matplotlib
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)

# %%
import ex2_1_ann_mnist_cl
reload(ex2_1_ann_mnist_cl)
# Out:
# Using TensorFlow backend.
# <module 'ex2_1_ann_mnist_cl' from '/home/sjkim/Dropbox/Aspuru-Guzik/python_lab/py3/keraspp/ex2_1_ann_mnist_cl.py'>

# %%
ex2_1_ann_mnist_cl.main()
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/15
# 48000/48000 [==============================] - 2s - loss: 0.3973 - acc: 0.8911 - val_loss: 0.2124 - val_acc: 0.9416
# Epoch 2/15
# 48000/48000 [==============================] - 1s - loss: 0.1872 - acc: 0.9462 - val_loss: 0.1583 - val_acc: 0.9548
# Epoch 3/15
# 48000/48000 [==============================] - 1s - loss: 0.1361 - acc: 0.9610 - val_loss: 0.1316 - val_acc: 0.9633
# Epoch 4/15
# 48000/48000 [==============================] - 1s - loss: 0.1066 - acc: 0.9699 - val_loss: 0.1218 - val_acc: 0.9648
# Epoch 5/15
# 48000/48000 [==============================] - 1s - loss: 0.0869 - acc: 0.9746 - val_loss: 0.1063 - val_acc: 0.9682
# Epoch 6/15
# 48000/48000 [==============================] - 1s - loss: 0.0728 - acc: 0.9791 - val_loss: 0.1006 - val_acc: 0.9695
# Epoch 7/15
# 48000/48000 [==============================] - 1s - loss: 0.0617 - acc: 0.9823 - val_loss: 0.0977 - val_acc: 0.9711
# Epoch 8/15
# 48000/48000 [==============================] - 1s - loss: 0.0523 - acc: 0.9852 - val_loss: 0.0969 - val_acc: 0.9711
# Epoch 9/15
# 48000/48000 [==============================] - 1s - loss: 0.0456 - acc: 0.9871 - val_loss: 0.0984 - val_acc: 0.9708
# Epoch 10/15
# 48000/48000 [==============================] - 1s - loss: 0.0387 - acc: 0.9895 - val_loss: 0.0893 - val_acc: 0.9737
# Epoch 11/15
# 48000/48000 [==============================] - 1s - loss: 0.0330 - acc: 0.9908 - val_loss: 0.0894 - val_acc: 0.9729
# Epoch 12/15
# 48000/48000 [==============================] - 1s - loss: 0.0277 - acc: 0.9931 - val_loss: 0.0870 - val_acc: 0.9737
# Epoch 13/15
# 48000/48000 [==============================] - 1s - loss: 0.0238 - acc: 0.9942 - val_loss: 0.0864 - val_acc: 0.9745
# Epoch 14/15
# 48000/48000 [==============================] - 1s - loss: 0.0205 - acc: 0.9951 - val_loss: 0.0876 - val_acc: 0.9751
# Epoch 15/15
# 48000/48000 [==============================] - 1s - loss: 0.0179 - acc: 0.9958 - val_loss: 0.0934 - val_acc: 0.9738
#  7100/10000 [====================>.........] - ETA: 0sTest Loss and Accuracy -> [0.08378495636839943, 0.97599997878074651]
