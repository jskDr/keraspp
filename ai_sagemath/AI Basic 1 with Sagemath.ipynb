# %% [markdown]
# # AI Basics 1 with Sagemath

# %% [markdown]
# ## ReLu represented by Sagemath
# - Use piecewise()

# %%
f_relu = piecewise( [[(-oo,0),0],[(0,oo),x]])
show(plot(f_relu))
f_relu
# Out:
# Graphics object consisting of 1 graphics primitive
# piecewise(x|-->0 on (-oo, 0), x|-->x on (0, +oo); x)
