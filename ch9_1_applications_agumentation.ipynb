# %%
# %matplotlib inline

# %%
from keraspp import ch9_1_applications_agumentation

# %%
m = ch9_1_applications_agumentation.Machine()
m.run()
# Out:
# (800, 32, 32, 3) (800, 1)
# X_train shape: (800, 32, 32, 3)
# 800 train samples
# 200 test samples
# data.input_shape (32, 32, 3)
# (800, 32, 32, 3)
# Epoch 1/10
# 10/10 [==============================] - 79s - loss: 2.2959 - acc: 0.1240 - val_loss: 2.2410 - val_acc: 0.2350
# Epoch 2/10
# 10/10 [==============================] - 0s - loss: 2.2600 - acc: 0.1541 - val_loss: 2.1885 - val_acc: 0.2100
# Epoch 3/10
# 10/10 [==============================] - 0s - loss: 2.2192 - acc: 0.2087 - val_loss: 2.1672 - val_acc: 0.2450
# Epoch 4/10
# 10/10 [==============================] - 0s - loss: 2.1775 - acc: 0.2056 - val_loss: 2.1283 - val_acc: 0.2450
# Epoch 5/10
# 10/10 [==============================] - 0s - loss: 2.0924 - acc: 0.2362 - val_loss: 2.1489 - val_acc: 0.1850
# Epoch 6/10
# 10/10 [==============================] - 0s - loss: 2.0869 - acc: 0.2495 - val_loss: 2.1195 - val_acc: 0.2000
# Epoch 7/10
# ...
