# %%
# %matplotlib inline

# %%
import ex9_1_applications_agumentation
# Out:
# Using TensorFlow backend.

# %%
m = ex9_1_applications_agumentation.Machine()
m.run()
# Out:
# (800, 32, 32, 3) (800, 1)
# X_train shape: (800, 32, 32, 3)
# 800 train samples
# 200 test samples
# data.input_shape (32, 32, 3)
# (800, 32, 32, 3)
# Epoch 1/100
# 10/10 [==============================] - 47s - loss: 2.2952 - acc: 0.1223 - val_loss: 2.2411 - val_acc: 0.1550
# Epoch 2/100
# 10/10 [==============================] - 0s - loss: 2.2341 - acc: 0.1702 - val_loss: 2.1838 - val_acc: 0.2300
# Epoch 3/100
# 10/10 [==============================] - 0s - loss: 2.1821 - acc: 0.1864 - val_loss: 2.1005 - val_acc: 0.2800
# Epoch 4/100
# 10/10 [==============================] - 0s - loss: 2.1954 - acc: 0.1994 - val_loss: 2.1344 - val_acc: 0.2500
# Epoch 5/100
# 10/10 [==============================] - 0s - loss: 2.1027 - acc: 0.2474 - val_loss: 2.0089 - val_acc: 0.3150
# Epoch 6/100
# 10/10 [==============================] - 0s - loss: 2.0374 - acc: 0.2932 - val_loss: 2.1775 - val_acc: 0.2050
# Epoch 7/100
# ...
