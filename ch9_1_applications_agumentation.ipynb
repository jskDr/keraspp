# %%
# %matplotlib inline

# %%
from keraspp import ch9_1_applications_agumentation
# Out:
# Using TensorFlow backend.

# %%
m = ch9_1_applications_agumentation.Machine()
m.run()
# Out:
# (800, 32, 32, 3) (800, 1)
# X_train shape: (800, 32, 32, 3)
# 800 train samples
# 200 test samples
# data.input_shape (32, 32, 3)
# (800, 32, 32, 3)
# Epoch 1/100
# 10/10 [==============================] - 282s - loss: 2.3154 - acc: 0.1077 - val_loss: 2.2739 - val_acc: 0.1850
# Epoch 2/100
# 10/10 [==============================] - 0s - loss: 2.2554 - acc: 0.1518 - val_loss: 2.2397 - val_acc: 0.1150
# Epoch 3/100
# 10/10 [==============================] - 0s - loss: 2.1979 - acc: 0.1872 - val_loss: 2.2010 - val_acc: 0.1850
# Epoch 4/100
# 10/10 [==============================] - 0s - loss: 2.2003 - acc: 0.1906 - val_loss: 2.1280 - val_acc: 0.2150
# Epoch 5/100
# 10/10 [==============================] - 0s - loss: 2.1603 - acc: 0.2007 - val_loss: 2.1709 - val_acc: 0.2300
# Epoch 6/100
# 10/10 [==============================] - 0s - loss: 2.0685 - acc: 0.2457 - val_loss: 1.9490 - val_acc: 0.3150
# Epoch 7/100
# ...
